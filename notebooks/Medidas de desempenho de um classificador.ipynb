# %% [markdown]
# # Medidas de avaliação de modelos de classificação

# %% [markdown]
# 1. Acurácia: É a fração de predições corretas.

# %%
from IPython.display import Image
Image("img/acuracia.png")

# %% [markdown]
# Porém, a acurácia não é um bom indicador para problemas com classes desbalanceadas.
#
# Exemplo: SPAM vs. NOT SPAM

# %% [markdown]
# Para isso, existe uma outra forma de olhar para os erros/acertos do algoritmo. A chamada matriz de confusão que permite observar a relação entre resultados falsos/verdadeiros e negativos/positivos.

# %%
Image("img/matriz-confusao.png")

# %% [markdown]
# 2. Precisão

# %%
Image("img/precisao.png")

# %% [markdown]
# 3. Revocação (Recall)

# %%
Image("img/revocacao.png")

# %% [markdown]
# 4. Pontuação F1

# %%
Image("img/pontf1.png")

# %% [markdown]
# ## No vídeo anterior...

# %%
from sklearn import svm
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X,y = load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=13)

# %%
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
clf.predict(X_test)
# Out:
# array([1, 1, 0, 2, 2, 0, 2, 2, 0, 1, 2, 2, 1, 0, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 2, 0, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 1, 1, 0, 0, 2, 1, 2,
#        2])

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 0, 2, 2, 0, 2, 2, 0, 1, 2, 2, 1, 0, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 2, 0, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 1, 1, 0, 0, 2, 1, 2,
#        2])

# %%
y_test
# Out:
# array([1, 1, 0, 2, 2, 0, 2, 2, 0, 1, 2, 2, 1, 0, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 2, 0, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 1, 1, 0, 0, 2, 1, 2,
#        2])

# %%
clf.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # Prática: Métricas no SciKit-Learn

# %% [markdown]
# Referência: https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  0, 19]])

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      1.00      1.00        12
#    virginica       1.00      1.00      1.00        19
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
